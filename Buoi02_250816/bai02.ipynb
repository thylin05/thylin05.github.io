# %%
# %run SoSanh.py
# Out:
# Ket qua so sanh hai so thuc 2.50 va 6.80:
# 2.50     <     6.80:     True
# 2.50     <=     6.80:     True
# 2.50     >     6.80:    False
# 2.50     >=     6.80:    False
# 2.50     ==     6.80:    False
# 2.50     !=     6.80:     True

# %%
# %run Max3Num.py
# Out:
# Max(2, 5, 4) = 5
