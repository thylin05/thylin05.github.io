# %% [markdown]
# # CÂU 6

# %% [markdown]
# Đoạn code mẫu để tạo biểu đồ scatter plot hoặc heatmap để phân tích mối quan hệ giữa hai biến?

# %% [markdown]
# ### 1. Nạp thư viện

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 2. Dữ liệu mẫu

# %%
x = np.random.rand(100)
y = 2 * x + np.random.rand(100) * 0.1  # Mối quan hệ tuyến tính với nhiễu

# %% [markdown]
# ### 3. Scatter plot

# %%
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color='blue', alpha=0.6)
plt.title('Scatter Plot of Two Variables')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.show()

# %% [markdown]
# ### 4. Heatmap

# %%
data = np.corrcoef(x, y)
plt.figure(figsize=(5, 4))
sns.heatmap(data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # CÂU 7

# %% [markdown]
# Làm thế nào để trực quan hóa mối quan hệ giữa một biến số và một biến phân loại bằng biểu đồ boxplot hoặc violin plot trong Python?

# %% [markdown]
# ### 1. Nạp thư viện

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2. Tải dữ liệu mẫu

# %%
data = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
    'Value': [1, 2, 3, 4, 5, 6] + np.random.randn(6) * 0.5
})

# %% [markdown]
# ### 3. Boxplot

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Category', y='Value', data=data, color='lightblue')
plt.title('Boxplot: Value by Category')
plt.show()

# %% [markdown]
# ### 4. Violin plot

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='Category', y='Value', data=data, color='lightgreen')
plt.title('Violin Plot: Value by Category')
plt.show()
