# %% [markdown]
# # THỐNG KÊ MÔ TẢ - Bài tập thực hành 1

# %% [markdown]
# Thực hiện thống kê mô tả trên tập dữ liệu về phân loại chất lượng rượu đỏ. Dữ liệu lấy tại https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification

# %% [markdown]
# # 1. Nạp thư viện

# %%
import pandas as pd  
import numpy as np  
import seaborn as sns  
import matplotlib.pyplot as plt  
from sklearn.preprocessing import LabelEncoder # for encoding
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler 
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import scipy.stats as st

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
#!pip install lightgbm

# %% [markdown]
# ### 2. Tải dữ liệu

# %%
df = pd.read_csv("winequality-red.csv")  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### 3. Thống kê mô tả

# %%
df.describe().T.style.background_gradient(cmap = "Oranges")
# Out:
# <style type="text/css">
# #T_ad2a4_row0_col0, #T_ad2a4_row1_col0, #T_ad2a4_row1_col7, #T_ad2a4_row2_col0, #T_ad2a4_row2_col3, #T_ad2a4_row2_col4, #T_ad2a4_row2_col7, #T_ad2a4_row3_col0, #T_ad2a4_row4_col0, #T_ad2a4_row4_col1, #T_ad2a4_row4_col2, #T_ad2a4_row4_col3, #T_ad2a4_row4_col4, #T_ad2a4_row4_col5, #T_ad2a4_row4_col6, #T_ad2a4_row4_col7, #T_ad2a4_row5_col0, #T_ad2a4_row6_col0, #T_ad2a4_row7_col0, #T_ad2a4_row7_col2, #T_ad2a4_row7_col7, #T_ad2a4_row8_col0, #T_ad2a4_row9_col0, #T_ad2a4_row10_col0, #T_ad2a4_row11_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_ad2a4_row0_col1, #T_ad2a4_row10_col6 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_ad2a4_row0_col2, #T_ad2a4_row0_col7, #T_ad2a4_row3_col1, #T_ad2a4_row3_col7, #T_ad2a4_row8_col6 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_ad2a4_row0_col3 {
#   background-color: #f87f2c;
#   color: #f1f1f1;
# }
# #T_ad2a4_row0_col4 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_ad2a4_row0_col5 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_ad2a4_row0_col6 {
#   background-color: #fee2c7;
#   color: #000000;
# }
# #T_ad2a4_row1_col1, #T_ad2a4_row1_col5, #T_ad2a4_row1_col6, #T_ad2a4_row9_col6 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_ad2a4_row1_col2, #T_ad2a4_row2_col1, #T_ad2a4_row2_col2, #T_ad2a4_row2_col5, #T_ad2a4_row2_col6, #T_ad2a4_row8_col2, #T_ad2a4_row9_col2, #T_ad2a4_row9_col7 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_ad2a4_row1_col3, #T_ad2a4_row1_col4, #T_ad2a4_row7_col6, #T_ad2a4_row8_col7, #T_ad2a4_row9_col1, #T_ad2a4_row9_col5 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_ad2a4_row3_col2, #T_ad2a4_row3_col6, #T_ad2a4_row7_col4, #T_ad2a4_row9_col3 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_ad2a4_row3_col3 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_ad2a4_row3_col4, #T_ad2a4_row8_col5 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_ad2a4_row3_col5 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_ad2a4_row5_col1 {
#   background-color: #fdb77a;
#   color: #000000;
# }
# #T_ad2a4_row5_col2 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_ad2a4_row5_col3, #T_ad2a4_row7_col3, #T_ad2a4_row11_col1 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# #T_ad2a4_row5_col4 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_ad2a4_row5_col5 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_ad2a4_row5_col6 {
#   background-color: #fdb87c;
#   color: #000000;
# }
# #T_ad2a4_row5_col7 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_ad2a4_row6_col1, #T_ad2a4_row6_col2, #T_ad2a4_row6_col4, #T_ad2a4_row6_col5, #T_ad2a4_row6_col6, #T_ad2a4_row6_col7, #T_ad2a4_row10_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_ad2a4_row6_col3 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_ad2a4_row7_col1, #T_ad2a4_row9_col4 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_ad2a4_row7_col5, #T_ad2a4_row11_col2, #T_ad2a4_row11_col7 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_ad2a4_row8_col1 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_ad2a4_row8_col3 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_ad2a4_row8_col4 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_ad2a4_row10_col1, #T_ad2a4_row11_col4 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_ad2a4_row10_col2 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_ad2a4_row10_col4 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_ad2a4_row10_col5 {
#   background-color: #fdcb9b;
#   color: #000000;
# }
# #T_ad2a4_row10_col7 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_ad2a4_row11_col3 {
#   background-color: #fdb373;
#   color: #000000;
# }
# #T_ad2a4_row11_col5 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_ad2a4_row11_col6 {
#   background-color: #feead5;
#   color: #000000;
# }
# </style>
# <table id="T_ad2a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad2a4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ad2a4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ad2a4_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_ad2a4_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_ad2a4_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_ad2a4_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_ad2a4_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_ad2a4_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad2a4_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_ad2a4_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_ad2a4_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_ad2a4_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_ad2a4_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_ad2a4_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_ad2a4_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_ad2a4_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_ad2a4_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_ad2a4_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_ad2a4_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_ad2a4_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_ad2a4_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_ad2a4_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_ad2a4_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_ad2a4_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_ad2a4_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_ad2a4_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_ad2a4_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_ad2a4_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_ad2a4_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_ad2a4_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_ad2a4_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_ad2a4_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_ad2a4_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_ad2a4_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_ad2a4_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad2a4_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_ad2a4_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_ad2a4_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_ad2a4_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_ad2a4_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_ad2a4_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_ad2a4_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_ad2a4_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_ad2a4_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ad2a4_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_ad2a4_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_ad2a4_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_ad2a4_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_ad2a4_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_ad2a4_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_ad2a4_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_ad2a4_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_ad2a4_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_ad2a4_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td

# %% [markdown]
# # XỬ LÝ VÀ TRỰC QUAN HÓA DỮ LIỆU - Bài tập thực hành 1

# %% [markdown]
# Thực hiện trực quan hóa dữ liệu trên tập dữ liệu về phân loại chất lượng rượu đỏ. Dữ liệu lấy tại https://www.kaggle.com/code/eisgandar/red-wine-quality-eda-classification

# %%
df.rename(columns = {"fixed acidity": "fixed_acidity", "volatile acidity": "volatile_acidity",
                    "citric acid": "citric_acid", "residual sugar": "residual_sugar",
                    "chlorides": "chlorides", "free sulfur dioxide": "free_sulfur_dioxide",
                    "total sulfur dioxide": "total_sulfur_dioxide"}, inplace = True)

# %%
sns.set(style="whitegrid", font_scale=2)

# %% [markdown]
# ### Vẽ biểu đồ phân phối

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Đặt style chung
sns.set(style="whitegrid", font_scale=1.2)

# Danh sách các biến và màu tương ứng
cols = [
    ("fixed_acidity", "#003366"),
    ("volatile_acidity", "#336699"),
    ("citric_acid", "#66B2FF"),
    ("alcohol", "#800000"),
    ("residual_sugar", "#CC3333"),
    ("chlorides", "#FF6666")
]

# Vẽ 3 biểu đồ mỗi lượt
for i in range(0, len(cols), 3):
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    
    for ax, (col, color) in zip(axes, cols[i:i+3]):
        sns.histplot(data=df, x=col, bins=10, kde=True, color=color, ax=ax)
        ax.set_title(f"Distribution of '{col}'")
        ax.set_xlabel(col.replace("_", " ").title())
        ax.set_ylabel("Count")
    
    plt.tight_layout()
    plt.show()
